# %% [markdown]
# # Bách Khoa Toàn Thư Lập Trình Python
#
# Tài liệu này bao gồm các kiến thức lập trình từ cơ bản đến nâng cao, với các ví dụ và giải thích chi tiết.
#
# ## Mục lục
# 1. Kiến thức cơ bản
# 2. Kiểu dữ liệu và các phép toán
# 3. Cấu trúc điều khiển
# 4. Hàm và phương thức
# 5. Cấu trúc dữ liệu
# 6. Lập trình hướng đối tượng
# 7. Xử lý file
# 8. Thuật toán thông dụng
# 9. Chủ đề nâng cao

# %% [markdown]
# ## 1. Kiến thức cơ bản
#
# ### 1.1 Biến và kiểu dữ liệu
# - Số nguyên (int)
# - Số thực (float)
# - Chuỗi (str)
# - Boolean (bool)

# %%
# Ví dụ về các kiểu dữ liệu cơ bản
x = 10          # int
y = 3.14        # float
name = "Python" # str
is_true = True  # bool

print(f"x = {x}, kiểu: {type(x)}")
print(f"y = {y}, kiểu: {type(y)}")
print(f"name = {name}, kiểu: {type(name)}")
print(f"is_true = {is_true}, kiểu: {type(is_true)}")

# %% [markdown]
# ## 2. Kiểu dữ liệu và các phép toán
#
# ### 2.1 Phép toán số học
# - Cộng (+)
# - Trừ (-)
# - Nhân (*)
# - Chia (/)
# - Chia lấy phần nguyên (//)
# - Chia lấy dư (%)
# - Lũy thừa (**)

# %%
# Ví dụ về các phép toán
a = 10
b = 3

print(f"Cộng: {a} + {b} = {a + b}")
print(f"Trừ: {a} - {b} = {a - b}")
print(f"Nhân: {a} * {b} = {a * b}")
print(f"Chia: {a} / {b} = {a / b}")
print(f"Chia lấy nguyên: {a} // {b} = {a // b}")
print(f"Chia lấy dư: {a} % {b} = {a % b}")
print(f"Lũy thừa: {a} ** {b} = {a ** b}")

# %% [markdown]
# ## 3. Cấu trúc điều khiển
#
# ### 3.1 Câu lệnh if-elif-else

# %%
# Ví dụ về if-elif-else
def check_number(x):
    if x > 0:
        return "Số dương"
    elif x < 0:
        return "Số âm"
    else:
        return "Số không"

print(check_number(5))
print(check_number(-3))
print(check_number(0))

# %% [markdown]
# ### 3.2 Vòng lặp for và while

# %%
# Ví dụ về vòng lặp
# For loop
print("For loop:")
for i in range(5):
    print(i, end=" ")

print("\n\nWhile loop:")
# While loop
count = 0
while count < 5:
    print(count, end=" ")
    count += 1

# %% [markdown]
# ## 4. Cấu trúc dữ liệu
#
# ### 4.1 List

# %%
# Các thao tác với list
numbers = [1, 2, 3, 4, 5]

# Thêm phần tử
numbers.append(6)
print("Sau khi thêm:", numbers)

# Xóa phần tử
numbers.pop()
print("Sau khi xóa:", numbers)

# Slice
print("Hai phần tử đầu:", numbers[:2])
print("Hai phần tử cuối:", numbers[-2:])

# %% [markdown]
# ### 4.2 Dictionary

# %%
# Thao tác với dictionary
student = {
    "name": "John",
    "age": 20,
    "grades": [85, 90, 95]
}

# Truy cập giá trị
print(f"Tên: {student['name']}")
print(f"Tuổi: {student['age']}")
print(f"Điểm: {student['grades']}")

# Thêm/cập nhật
student['email'] = 'john@example.com'
print("\nSau khi thêm email:", student)

# %% [markdown]
# ## 5. Lập trình hướng đối tượng
#
# ### 5.1 Class và Object

# %%
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age
    
    def introduce(self):
        return f"Tôi tên là {self.name}, {self.age} tuổi"

# Tạo đối tượng
person = Person("Alice", 25)
print(person.introduce())

# %% [markdown]
# ## 6. Thuật toán thông dụng
#
# ### 6.1 Sắp xếp

# %%
# Bubble sort
def bubble_sort(arr):
    n = len(arr)
    for i in range(n):
        for j in range(0, n-i-1):
            if arr[j] > arr[j+1]:
                arr[j], arr[j+1] = arr[j+1], arr[j]
    return arr

# Quick sort
def quick_sort(arr):
    if len(arr) <= 1:
        return arr
    pivot = arr[len(arr) // 2]
    left = [x for x in arr if x < pivot]
    middle = [x for x in arr if x == pivot]
    right = [x for x in arr if x > pivot]
    return quick_sort(left) + middle + quick_sort(right)

# Test
arr = [64, 34, 25, 12, 22, 11, 90]
print("Bubble sort:", bubble_sort(arr.copy()))
print("Quick sort:", quick_sort(arr.copy()))

# %% [markdown]
# ### 6.2 Tìm kiếm

# %%
# Tìm kiếm tuyến tính
def linear_search(arr, x):
    for i in range(len(arr)):
        if arr[i] == x:
            return i
    return -1

# Tìm kiếm nhị phân
def binary_search(arr, x):
    left, right = 0, len(arr) - 1
    while left <= right:
        mid = (left + right) // 2
        if arr[mid] == x:
            return mid
        elif arr[mid] < x:
            left = mid + 1
        else:
            right = mid - 1
    return -1

# Test
arr = [1, 3, 5, 7, 9, 11, 13]
x = 7
print(f"Linear search: phần tử {x} ở vị trí {linear_search(arr, x)}")
print(f"Binary search: phần tử {x} ở vị trí {binary_search(arr, x)}")

# %% [markdown]
# ## 7. Chủ đề nâng cao
#
# ### 7.1 List Comprehension

# %%
# List comprehension examples
numbers = [1, 2, 3, 4, 5]

# Bình phương các số
squares = [x**2 for x in numbers]
print("Bình phương:", squares)

# Lọc số chẵn
even = [x for x in numbers if x % 2 == 0]
print("Số chẵn:", even)

# Kết hợp điều kiện
result = [x if x % 2 == 0 else x**2 for x in numbers]
print("Kết hợp điều kiện:", result)

# %% [markdown]
# ### 7.2 Lambda Functions

# %%
# Lambda function examples
# Hàm bình phương
square = lambda x: x**2

# Hàm tổng hai số
add = lambda x, y: x + y

# Sử dụng với map
numbers = [1, 2, 3, 4, 5]
squared = list(map(square, numbers))

print(f"Bình phương của 5: {square(5)}")
print(f"Tổng 3 và 4: {add(3, 4)}")
print(f"Map với square: {squared}")

# %% [markdown]
# ### 7.3 Generators

# %% [markdown]
# ## 8. Cấu trúc dữ liệu nâng cao cho PE
#
# ### 8.1 Linked List
# Danh sách liên kết là một cấu trúc dữ liệu tuyến tính, trong đó mỗi phần tử (node) chứa dữ liệu và tham chiếu đến node tiếp theo.

# %%
# Cài đặt Node cho Linked List
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

class LinkedList:
    def __init__(self):
        self.head = None
    
    # Thêm node vào đầu danh sách
    def addFirst(self, data):
        new_node = Node(data)
        new_node.next = self.head
        self.head = new_node
    
    # Thêm node vào cuối danh sách
    def addLast(self, data):
        new_node = Node(data)
        if not self.head:
            self.head = new_node
            return
        current = self.head
        while current.next:
            current = current.next
        current.next = new_node
    
    # Xóa node đầu tiên
    def removeFirst(self):
        if not self.head:
            return None
        removed_data = self.head.data
        self.head = self.head.next
        return removed_data
    
    # Xóa node cuối cùng
    def removeLast(self):
        if not self.head:
            return None
        if not self.head.next:
            removed_data = self.head.data
            self.head = None
            return removed_data
        current = self.head
        while current.next.next:
            current = current.next
        removed_data = current.next.data
        current.next = None
        return removed_data
    
    # Duyệt danh sách
    def traverse(self):
        result = []
        current = self.head
        while current:
            result.append(current.data)
            current = current.next
        return result
    
    # Tìm giá trị lớn nhất
    def findMax(self):
        if not self.head:
            return None
        max_val = self.head.data
        current = self.head.next
        while current:
            if current.data > max_val:
                max_val = current.data
            current = current.next
        return max_val
    
    # Tìm giá trị nhỏ nhất
    def findMin(self):
        if not self.head:
            return None
        min_val = self.head.data
        current = self.head.next
        while current:
            if current.data < min_val:
                min_val = current.data
            current = current.next
        return min_val

# Ví dụ sử dụng
ll = LinkedList()
ll.addFirst(3)
ll.addLast(7)
ll.addFirst(1)
ll.addLast(9)
print("Danh sách:", ll.traverse())
print("Giá trị lớn nhất:", ll.findMax())
print("Giá trị nhỏ nhất:", ll.findMin())
print("Xóa đầu:", ll.removeFirst())
print("Xóa cuối:", ll.removeLast())
print("Danh sách sau khi xóa:", ll.traverse())

# %% [markdown]
# ### 8.2 Queue (Hàng đợi)
# Queue là một cấu trúc dữ liệu hoạt động theo nguyên tắc FIFO (First In First Out). Phần tử được thêm vào cuối hàng đợi và lấy ra từ đầu hàng đợi.

# %%
# Cài đặt Queue sử dụng Linked List
class Queue:
    def __init__(self):
        self.front = None
        self.rear = None
    
    # Kiểm tra queue rỗng
    def isEmpty(self):
        return self.front is None
    
    # Thêm phần tử vào cuối queue
    def enQueue(self, data):
        new_node = Node(data)
        if self.rear is None:
            self.front = self.rear = new_node
            return
        self.rear.next = new_node
        self.rear = new_node
    
    # Lấy phần tử từ đầu queue
    def deQueue(self):
        if self.isEmpty():
            return None
        temp = self.front
        self.front = temp.next
        if self.front is None:
            self.rear = None
        return temp.data
    
    # Xem phần tử đầu queue mà không xóa
    def peek(self):
        if self.isEmpty():
            return None
        return self.front.data
    
    # Duyệt queue
    def traverse(self):
        result = []
        current = self.front
        while current:
            result.append(current.data)
            current = current.next
        return result

# Ví dụ sử dụng
q = Queue()
q.enQueue(1)
q.enQueue(2)
q.enQueue(3)
print("Queue:", q.traverse())
print("Peek:", q.peek())
print("DeQueue:", q.deQueue())
print("Queue sau deQueue:", q.traverse())

# %% [markdown]
# ### 8.3 Stack (Ngăn xếp)
# Stack là một cấu trúc dữ liệu hoạt động theo nguyên tắc LIFO (Last In First Out). Phần tử được thêm vào và lấy ra từ cùng một đầu của stack.

# %%
# Cài đặt Stack sử dụng Linked List
class Stack:
    def __init__(self):
        self.top = None
    
    # Kiểm tra stack rỗng
    def isEmpty(self):
        return self.top is None
    
    # Thêm phần tử vào đỉnh stack
    def push(self, data):
        new_node = Node(data)
        new_node.next = self.top
        self.top = new_node
    
    # Lấy phần tử từ đỉnh stack
    def pop(self):
        if self.isEmpty():
            return None
        temp = self.top
        self.top = self.top.next
        return temp.data
    
    # Xem phần tử đỉnh stack mà không xóa
    def peek(self):
        if self.isEmpty():
            return None
        return self.top.data
    
    # Duyệt stack
    def traverse(self):
        result = []
        current = self.top
        while current:
            result.append(current.data)
            current = current.next
        return result

# Ví dụ sử dụng
s = Stack()
s.push(1)
s.push(2)
s.push(3)
print("Stack:", s.traverse())
print("Peek:", s.peek())
print("Pop:", s.pop())
print("Stack sau pop:", s.traverse())

# %% [markdown]
# ### 8.4 Binary Search Tree (Cây nhị phân tìm kiếm)
# BST là một cấu trúc dữ liệu dạng cây mà mỗi node có tối đa hai node con. Với mỗi node, giá trị của tất cả các node con bên trái nhỏ hơn giá trị của node hiện tại, và giá trị của tất cả các node con bên phải lớn hơn giá trị của node hiện tại.

# %%
# Cài đặt Node cho BST
class TreeNode:
    def __init__(self, data):
        self.data = data
        self.left = None
        self.right = None

class BST:
    def __init__(self):
        self.root = None
    
    # Thêm node mới vào BST
    def insert(self, data):
        if not self.root:
            self.root = TreeNode(data)
        else:
            self._insert_recursive(self.root, data)
    
    def _insert_recursive(self, node, data):
        if data < node.data:
            if node.left is None:
                node.left = TreeNode(data)
            else:
                self._insert_recursive(node.left, data)
        else:
            if node.right is None:
                node.right = TreeNode(data)
            else:
                self._insert_recursive(node.right, data)
    
    # Xóa node khỏi BST
    def delete(self, data):
        self.root = self._delete_recursive(self.root, data)
    
    def _delete_recursive(self, root, data):
        if root is None:
            return root
        
        if data < root.data:
            root.left = self._delete_recursive(root.left, data)
        elif data > root.data:
            root.right = self._delete_recursive(root.right, data)
        else:
            # Node với một hoặc không có con
            if root.left is None:
                return root.right
            elif root.right is None:
                return root.left
            
            # Node với hai con
            temp = self._min_value_node(root.right)
            root.data = temp.data
            root.right = self._delete_recursive(root.right, temp.data)
        
        return root
    
    def _min_value_node(self, node):
        current = node
        while current.left:
            current = current.left
        return current
    
    # Duyệt cây theo thứ tự giữa (Inorder)
    def inorder(self):
        result = []
        self._inorder_recursive(self.root, result)
        return result
    
    def _inorder_recursive(self, root, result):
        if root:
            self._inorder_recursive(root.left, result)
            result.append(root.data)
            self._inorder_recursive(root.right, result)
    
    # Tìm giá trị nhỏ nhất
    def findMin(self):
        if not self.root:
            return None
        current = self.root
        while current.left:
            current = current.left
        return current.data
    
    # Tìm giá trị lớn nhất
    def findMax(self):
        if not self.root:
            return None
        current = self.root
        while current.right:
            current = current.right
        return current.data
    
    # Tìm kiếm một giá trị
    def search(self, data):
        return self._search_recursive(self.root, data)
    
    def _search_recursive(self, root, data):
        if root is None or root.data == data:
            return root
        if data < root.data:
            return self._search_recursive(root.left, data)
        return self._search_recursive(root.right, data)

# Ví dụ sử dụng
bst = BST()
nums = [5, 3, 7, 1, 4, 6, 8]
for num in nums:
    bst.insert(num)

print("Duyệt inorder:", bst.inorder())
print("Giá trị nhỏ nhất:", bst.findMin())
print("Giá trị lớn nhất:", bst.findMax())
bst.delete(3)
print("Sau khi xóa 3:", bst.inorder())

# %% [markdown]
# ### 8.5 Ví dụ kết hợp các cấu trúc dữ liệu
#
# Dưới đây là một số ví dụ về việc kết hợp các cấu trúc dữ liệu để giải quyết các bài toán phức tạp hơn:

# %%
# Ví dụ 1: Kết hợp LinkedList và Queue
# Quản lý hàng đợi xử lý tác vụ với độ ưu tiên
class PriorityTask:
    def __init__(self, task, priority):
        self.task = task
        self.priority = priority

class PriorityTaskManager:
    def __init__(self):
        self.high_priority = Queue()  # Queue cho tác vụ ưu tiên cao
        self.low_priority = Queue()   # Queue cho tác vụ ưu tiên thấp
        
    def addTask(self, task, priority):
        if priority > 5:  # Ưu tiên cao
            self.high_priority.enQueue(PriorityTask(task, priority))
        else:  # Ưu tiên thấp
            self.low_priority.enQueue(PriorityTask(task, priority))
    
    def processNextTask(self):
        # Xử lý tác vụ ưu tiên cao trước
        if not self.high_priority.isEmpty():
            task = self.high_priority.deQueue()
            return f"Xử lý tác vụ ưu tiên cao: {task.task} (priority: {task.priority})"
        elif not self.low_priority.isEmpty():
            task = self.low_priority.deQueue()
            return f"Xử lý tác vụ ưu tiên thấp: {task.task} (priority: {task.priority})"
        return "Không có tác vụ nào trong hàng đợi"

# Ví dụ sử dụng
task_manager = PriorityTaskManager()
task_manager.addTask("Task 1", 7)
task_manager.addTask("Task 2", 3)
task_manager.addTask("Task 3", 8)
task_manager.addTask("Task 4", 4)

print(task_manager.processNextTask())
print(task_manager.processNextTask())
print(task_manager.processNextTask())
print(task_manager.processNextTask())

# %%
# Ví dụ 2: Kết hợp BST và Stack
# Duyệt cây nhị phân không đệ quy bằng Stack
class TreeTraversal:
    def __init__(self):
        self.bst = BST()
        self.stack = Stack()
    
    def insert_values(self, values):
        for value in values:
            self.bst.insert(value)
    
    # Duyệt theo thứ tự trước (Preorder) không đệ quy
    def preorder_iterative(self):
        if not self.bst.root:
            return []
        
        result = []
        self.stack = Stack()
        self.stack.push(self.bst.root)
        
        while not self.stack.isEmpty():
            node = self.stack.pop()
            result.append(node.data)
            
            # Push right trước để xử lý left trước (vì stack LIFO)
            if node.right:
                self.stack.push(node.right)
            if node.left:
                self.stack.push(node.left)
        
        return result
    
    # Tính tổng các node lá (node không có con)
    def sum_leaf_nodes(self):
        if not self.bst.root:
            return 0
        
        total = 0
        self.stack = Stack()
        self.stack.push(self.bst.root)
        
        while not self.stack.isEmpty():
            node = self.stack.pop()
            
            # Kiểm tra node lá
            if not node.left and not node.right:
                total += node.data
            
            if node.right:
                self.stack.push(node.right)
            if node.left:
                self.stack.push(node.left)
        
        return total

# Ví dụ sử dụng
tree = TreeTraversal()
tree.insert_values([10, 5, 15, 3, 7, 12, 18])

print("Duyệt preorder:", tree.preorder_iterative())
print("Tổng các node lá:", tree.sum_leaf_nodes())

# %%
# Generator function
def fibonacci(n):
    a, b = 0, 1
    for _ in range(n):
        yield a
        a, b = b, a + b

# Sử dụng generator
fib = fibonacci(10)
print("Dãy Fibonacci:")
for num in fib:
    print(num, end=" ")
